# %% [markdown]
# # Importing Data

# %%
import pandas as pd

df = pd.read_csv('recruitment_data.csv')

print(df.head)
# Out:
# <bound method NDFrame.head of       Age  Gender  EducationLevel  ExperienceYears  PreviousCompanies  \
# 0      26       1               2                0                  3
# 1      39       1               4               12                  3
# 2      48       0               2                3                  2
# 3      34       1               2                5                  2
# 4      30       0               1                6                  1
# ...   ...     ...             ...              ...                ...
# 1495   48       0               2                3                  4
# 1496   27       1               2               10                  3
# 1497   24       1               1                1                  2
# 1498   48       0               2                4                  4
# 1499   34       1               2               11                  5
#
#       DistanceFromCompany  InterviewScore  SkillScore  PersonalityScore  \
# ...

# %% [markdown]
# # Standardizing Data
#
# There doesn't seem to be any missing values or scaling numerical values. So I will just remove values that are inconsistent by the age-experience metric.

# %%
exp_condition = df['Age'] - df['ExperienceYears'] >= 15
df_cleaned = df[exp_condition]
print(df_cleaned.head)
# Out:
# <bound method NDFrame.head of       Age  Gender  EducationLevel  ExperienceYears  PreviousCompanies  \
# 0      26       1               2                0                  3
# 1      39       1               4               12                  3
# 2      48       0               2                3                  2
# 3      34       1               2                5                  2
# 4      30       0               1                6                  1
# ...   ...     ...             ...              ...                ...
# 1495   48       0               2                3                  4
# 1496   27       1               2               10                  3
# 1497   24       1               1                1                  2
# 1498   48       0               2                4                  4
# 1499   34       1               2               11                  5
#
#       DistanceFromCompany  InterviewScore  SkillScore  PersonalityScore  \
# ...
